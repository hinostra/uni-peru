# %% [markdown]
# # Clusterización de Asteroides

# %%
import pandas as pd
import numpy as np
pd.set_option("display.precision",2)

# %%
df = pd.read_csv("neos.csv")

# %%
df_haz = df[df['Hazardous']]

# %% [markdown]
# **Amors**

# %%
amors_1 = df_haz[df_haz['Semi Major Axis'] > 1]
amors_2 = amors_1[amors_1['Perihelion Distance'] > 1.017]
amors_3 = amors_2[amors_2['Perihelion Distance'] < 1.3]
amors_3
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 359            3409688  3409688                21.7                0.12
# 675            2038071  2038071                19.6                0.32
# 837            2423321  2423321                20.8                0.18
# 899            3046122  3046122                19.1                0.40
# 1061           3606252  3606252                20.6                0.20
# 1160           3720978  3720978                20.3                0.23
# 1207           3120892  3120892                19.4                0.35
# 1250           3132128  3132128                21.9                0.11
# 1369           3582516  3582516                21.7                0.12
# 1634           3253151  3253151                22.0                0.11
# 2438           3429819  3429819                21.8                0.12
# 3135           3249347  3249347                21.3                0.15
# ...

# %% [markdown]
# **Apollos**

# %%
apollos_1 = df_haz[df_haz['Semi Major Axis'] > 1]
apollos_2 = apollos_1[apollos_1['Perihelion Distance'] < 1.017]
apollos_2
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0              3703080  3703080                21.6                0.13
# 2              2446862  2446862                20.3                0.23
# 4              3514799  3514799                21.6                0.13
# 25             3646046  3646046                21.3                0.15
# 27             2162173  2162173                19.3                0.37
# ...                ...      ...                 ...                 ...
# 4662           3744785  3744785                19.3                0.37
# 4663           3755345  3755345                21.5                0.13
# 4665           2333578  2333578                20.2                0.24
# 4668           3475236  3475236                21.6                0.13
# 4674           2068346  2068346                16.9                1.11
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# ...

# %% [markdown]
# **Atens**

# %%
atens_1 = df_haz[df_haz['Semi Major Axis'] < 1]
atens_2 = atens_1[atens_1['Aphelion Dist'] > 0.983]
atens_2
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 9              2306383  2306383                21.5                0.13
# 22             3005973  3005973                21.7                0.12
# 77             2308242  2308242                16.5                1.33
# 83             2216523  2216523                20.6                0.20
# 100            3390647  3390647                22.0                0.11
# ...                ...      ...                 ...                 ...
# 4395           2230111  2230111                19.1                0.40
# 4535           3152317  3152317                21.2                0.15
# 4573           3752784  3752784                21.3                0.15
# 4603           3522123  3522123                20.8                0.18
# 4609           2468727  2468727                20.8                0.18
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# ...

# %% [markdown]
# **Atiras**

# %%
atiras_1 = df_haz[df_haz['Semi Major Axis'] < 1]
atiras_2 = atiras_1[atiras_1['Aphelion Dist'] < 0.983]
atiras_2
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 95             3666783  3666783                20.3                0.23
# 1736           2434326  2434326                18.4                0.56
# 2147           2434326  2434326                18.4                0.56
# 2385           2434326  2434326                18.4                0.56
# 3861           3666783  3666783                20.3                0.23
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# 95                  0.52             231.50             517.65
# 1736                1.24             555.33            1241.77
# 2147                1.24             555.33            1241.77
# 2385                1.24             555.33            1241.77
# 3861                0.52             231.50             517.65
#
#       Est Dia in Miles(min)  Est Dia in Miles(max)  Est Dia in Feet(min)  ...  \
# ...
